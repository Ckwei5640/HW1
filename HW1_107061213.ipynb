# %%
# Part. 1
#=======================================
# Import module
#  csv -- fileIO operation
import csv
#=======================================

# Part. 2
#=======================================
# Read cwb weather data
cwb_filename = '107061213.csv'
data = []
header = []
with open(cwb_filename) as csvfile:
   mycsv = csv.DictReader(csvfile)
   header = mycsv.fieldnames
   for row in mycsv:
      data.append(row)
#=======================================

# Part. 3
#=======================================
# Analyze data depend on your group and store it to target_data like:
# Retrive all data points which station id is "C0X260" as a list.
# target_data = list(filter(lambda item: item['station_id'] == 'C0X260', data))
# C0A880, C0F9A0, C0G640, C0R190, C0X260

filt_data = list(filter(lambda item: 
                         (item['HUMD'] != '-99.000') & ((item['station_id'] == 'C0A880') | (item['station_id'] == 'C0F9A0') | (item['station_id'] == 'C0G640') | (item['station_id'] == 'C0R190') | (item['station_id'] == 'C0X260')), data)) 
         # 提取C0A880, C0F9A0, C0G640, C0R190, C0X260的測站資料

station = []
humd = []

for i in filt_data:
    if(i['station_id'] not in station):
        station.append(i['station_id'])
        humd.append(i['HUMD'])
    else:
        humd[station.index(i['station_id'])] = float(humd[station.index(i['station_id'])]) + float(i['HUMD'])  # sum up

for i in ['C0A880', 'C0F9A0', 'C0G640', 'C0R190', 'C0X260']:
    if(i not in station):        
        station.append(i),
        humd.append("None")    #檢查有沒有'沒資料的station'


# Retrive ten data points from the beginning.
target_data=[]
for i,j in zip(station,humd):    # 用zip將station & humd打包成tuple 形成list
    target_data.append([i,j])

target_data = sorted(target_data)  # 依照字母順序排列測站資料
#=======================================

# Part. 4
#=======================================
# Print result
print(target_data)
#========================================
# Out:
# [['C0A880', 20.37], ['C0F9A0', 19.410000000000004], ['C0G640', 19.499999999999993], ['C0R190', 20.970000000000002], ['C0X260', 19.760000000000005]]

# %%
filt_data
# Out:
# [OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '00:00'),
#               ('WDSD', '12.0'),
#               ('TEMP', '22.0'),
#               ('HUMD', '0.65'),
#               ('PRES', '1007.0')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '12:00'),
#               ('WDSD', '11.0'),
#               ('TEMP', '22.0'),
#               ('HUMD', '0.67'),
#               ('PRES', '1014.3')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '12:00'),
#               ('WDSD', '17.0'),
#               ('TEMP', '28.0'),
#               ('HUMD', '0.43'),
#               ('PRES', '995.1')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '00:00'),
#               ('WDSD', '0.0'),
#               ('TEMP', '-99.000'),
#               ('HUMD', '0.53'),
#               ('PRES', '-99.000')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '12:00'),
#               ('WDSD', '19.0'),
#               ('TEMP', '27.0'),
#               ('HUMD', '0.55'),
#               ('PRES', '-99.000')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '00:00'),
#               ('WDSD', '-99.000'),
#               ('TEMP', '-99.000'),
#               ('HUMD', '0.67'),
#               ('PRES', '1018.5')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '12:00'),
#               ('WDSD', '19.0'),
#               ('TEMP', '-99.000'),
#               ('HUMD', '0.69'),
#               ('PRES', '1017.4')])]

# %%
filt_data
# Out:
# [OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 00:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '84.000'),
#               ('WDSD', '2.300'),
#               ('TEMP', '24.800'),
#               ('HUMD', '0.830'),
#               ('PRES', '1016.200'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '25.400'),
#               ('D_TXT', ''),
#               ('D_TN', '20.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 00:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '26.000'),
#               ('WDSD', '0.600'),
#               ('TEMP', '24.800'),
#               ('HUMD', '0.910'),
#               ('PRES', '1012.300'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '32.700'),
#               ('D_TXT', ''),
#               ('D_TN', '21.700'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 00:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.100'),
#               ('TEMP', '23.800'),
#               ('HUMD', '0.970'),
#               ('PRES', '1011.700'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '31.800'),
#               ('D_TXT', ''),
#               ('D_TN', '23.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 00:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '205.000'),
#               ('WDSD', '0.800'),
#               ('TEMP', '23.200'),
#               ('HUMD', '0.970'),
#               ('PRES', '968.100'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.900'),
#               ('D_TXT', ''),
#               ('D_TN', '21.000'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 00:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '22.000'),
#               ('WDSD', '2.000'),
#               ('TEMP', '24.800'),
#               ('HUMD', '0.850'),
#               ('PRES', '1015.700'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.600'),
#               ('D_TXT', ''),
#               ('D_TN', '21.200'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 01:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '28.000'),
#               ('WDSD', '1.000'),
#               ('TEMP', '24.500'),
#               ('HUMD', '0.850'),
#               ('PRES', '1015.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.800'),
#               ('D_TXT', ''),
#               ('D_TN', '24.500'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 01:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.000'),
#               ('TEMP', '24.700'),
#               ('HUMD', '0.920'),
#               ('PRES', '1011.700'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.700'),
#               ('D_TXT', ''),
#               ('D_TN', '24.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 01:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.000'),
#               ('TEMP', '23.400'),
#               ('HUMD', '0.970'),
#               ('PRES', '1011.400'),
#               ('SUN', ''),
#               ('H_24R', '-99.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '23.900'),
#               ('D_TXT', ''),
#               ('D_TN', '23.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 01:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '143.000'),
#               ('WDSD', '0.600'),
#               ('TEMP', '22.900'),
#               ('HUMD', '0.970'),
#               ('PRES', '967.800'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '23.300'),
#               ('D_TXT', ''),
#               ('D_TN', '22.900'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 01:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '115.000'),
#               ('WDSD', '1.700'),
#               ('TEMP', '23.900'),
#               ('HUMD', '0.900'),
#               ('PRES', '1015.900'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 02:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '41.000'),
#               ('WDSD', '2.600'),
#               ('TEMP', '23.600'),
#               ('HUMD', '0.930'),
#               ('PRES', '1014.900'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 02:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '24.000'),
#               ('WDSD', '1.300'),
#               ('TEMP', '24.100'),
#               ('HUMD', '0.870'),
#               ('PRES', '1014.700'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.800'),
#               ('D_TXT', ''),
#               ('D_TN', '24.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 02:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '27.000'),
#               ('WDSD', '0.700'),
#               ('TEMP', '24.300'),
#               ('HUMD', '0.940'),
#               ('PRES', '1010.900'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.700'),
#               ('D_TXT', ''),
#               ('D_TN', '24.300'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 02:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.000'),
#               ('TEMP', '23.300'),
#               ('HUMD', '0.980'),
#               ('PRES', '1010.600'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '23.900'),
#               ('D_TXT', ''),
#               ('D_TN', '23.200'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 02:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '261.000'),
#               ('WDSD', '0.600'),
#               ('TEMP', '22.600'),
#               ('HUMD', '0.970'),
#               ('PRES', '967.000'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '23.300'),
#               ('D_TXT', ''),
#               ('D_TN', '22.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 03:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '57.000'),
#               ('WDSD', '0.700'),
#               ('TEMP', '24.200'),
#               ('HUMD', '0.940'),
#               ('PRES', '1010.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.700'),
#               ('D_TXT', ''),
#               ('D_TN', '24.200'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 03:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.000'),
#               ('TEMP', '22.900'),
#               ('HUMD', '0.980'),
#               ('PRES', '1010.200'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '23.900'),
#               ('D_TXT', ''),
#               ('D_TN', '22.900'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 03:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '136.000'),
#               ('WDSD', '0.600'),
#               ('TEMP', '22.500'),
#               ('HUMD', '0.980'),
#               ('PRES', '966.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '23.300'),
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 03:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '36.000'),
#               ('WDSD', '2.600'),
#               ('TEMP', '23.500'),
#               ('HUMD', '0.930'),
#               ('PRES', '1014.600'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 03:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '17.000'),
#               ('WDSD', '1.200'),
#               ('TEMP', '23.800'),
#               ('HUMD', '0.880'),
#               ('PRES', '1014.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.800'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 04:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '55.000'),
#               ('WDSD', '1.000'),
#               ('TEMP', '24.200'),
#               ('HUMD', '0.900'),
#               ('PRES', '1014.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 04:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '17.000'),
#               ('WDSD', '2.200'),
#               ('TEMP', '24.000'),
#               ('HUMD', '0.880'),
#               ('PRES', '1014.300'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.800'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 04:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '141.000'),
#               ('WDSD', '0.300'),
#               ('TEMP', '22.000'),
#               ('HUMD', '0.980'),
#               ('PRES', '966.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '23.300'),
#               ('D_TXT', ''),
#               ('D_TN', '22.000'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 04:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.000'),
#               ('TEMP', '24.000'),
#               ('HUMD', '0.950'),
#               ('PRES', '1010.600'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.700'),
#               ('D_TXT', ''),
#               ('D_TN', '24.000'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 04:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.000'),
#               ('TEMP', '22.800'),
#               ('HUMD', '0.990'),
#               ('PRES', '1010.000'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '23.900'),
#               ('D_TXT', ''),
#               ('D_TN', '22.700'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 05:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '13.000'),
#               ('WDSD', '2.100'),
#               ('TEMP', '24.000'),
#               ('HUMD', '0.880'),
#               ('PRES', '1014.400'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.800'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 05:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '64.000'),
#               ('WDSD', '1.300'),
#               ('TEMP', '24.400'),
#               ('HUMD', '0.880'),
#               ('PRES', '1014.600'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '6.600'),
#               ('H_XD', '63.000'),
#               ('H_FXT', ''),
#               ('D_TX', '24.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 05:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '13.000'),
#               ('WDSD', '0.900'),
#               ('TEMP', '23.300'),
#               ('HUMD', '0.970'),
#               ('PRES', '1010.300'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.700'),
#               ('D_TXT', ''),
#               ('D_TN', '23.300'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 05:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.200'),
#               ('TEMP', '22.600'),
#               ('HUMD', '0.990'),
#               ('PRES', '1010.100'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '23.900'),
#               ('D_TXT', ''),
#               ('D_TN', '22.500'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 05:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '348.000'),
#               ('WDSD', '0.800'),
#               ('TEMP', '22.300'),
#               ('HUMD', '0.980'),
#               ('PRES', '966.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '23.300'),
#               ('D_TXT', ''),
#               ('D_TN', '22.000'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 06:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '81.000'),
#               ('WDSD', '0.800'),
#               ('TEMP', '21.700'),
#               ('HUMD', '0.990'),
#               ('PRES', '966.800'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '23.300'),
#               ('D_TXT', ''),
#               ('D_TN', '21.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 06:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '39.000'),
#               ('WDSD', '1.800'),
#               ('TEMP', '24.400'),
#               ('HUMD', '0.880'),
#               ('PRES', '1014.800'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 06:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '24.000'),
#               ('WDSD', '1.500'),
#               ('TEMP', '24.100'),
#               ('HUMD', '0.880'),
#               ('PRES', '1014.700'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.800'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 06:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '14.000'),
#               ('WDSD', '1.100'),
#               ('TEMP', '23.300'),
#               ('HUMD', '0.960'),
#               ('PRES', '1010.800'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.700'),
#               ('D_TXT', ''),
#               ('D_TN', '23.300'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 06:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.000'),
#               ('TEMP', '22.500'),
#               ('HUMD', '1.000'),
#               ('PRES', '1010.700'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '23.900'),
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 07:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '15.000'),
#               ('WDSD', '1.300'),
#               ('TEMP', '24.700'),
#               ('HUMD', '0.870'),
#               ('PRES', '1014.900'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.800'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 07:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '17.000'),
#               ('WDSD', '0.900'),
#               ('TEMP', '23.700'),
#               ('HUMD', '0.950'),
#               ('PRES', '1011.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.700'),
#               ('D_TXT', ''),
#               ('D_TN', '23.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 07:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '47.000'),
#               ('WDSD', '0.700'),
#               ('TEMP', '22.600'),
#               ('HUMD', '1.000'),
#               ('PRES', '1011.000'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '23.900'),
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 07:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '297.000'),
#               ('WDSD', '0.500'),
#               ('TEMP', '23.100'),
#               ('HUMD', '0.960'),
#               ('PRES', '966.900'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '23.300'),
#               ('D_TXT', ''),
#               ('D_TN', '21.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 07:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '33.000'),
#               ('WDSD', '3.000'),
#               ('TEMP', '24.300'),
#               ('HUMD', '0.900'),
#               ('PRES', '1014.700'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 08:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '32.000'),
#               ('WDSD', '1.400'),
#               ('TEMP', '24.600'),
#               ('HUMD', '0.900'),
#               ('PRES', '1015.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.600'),
#               ('D_TXT', ''),
#               ('D_TN', '23.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 08:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '18.000'),
#               ('WDSD', '2.900'),
#               ('TEMP', '26.400'),
#               ('HUMD', '0.790'),
#               ('PRES', '1015.400'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '26.400'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 08:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '78.000'),
#               ('WDSD', '0.300'),
#               ('TEMP', '27.100'),
#               ('HUMD', '0.700'),
#               ('PRES', '967.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '27.100'),
#               ('D_TXT', ''),
#               ('D_TN', '21.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 08:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '107.000'),
#               ('WDSD', '0.700'),
#               ('TEMP', '25.800'),
#               ('HUMD', '0.880'),
#               ('PRES', '1011.600'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '25.800'),
#               ('D_TXT', ''),
#               ('D_TN', '23.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 08:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '119.000'),
#               ('WDSD', '0.300'),
#               ('TEMP', '26.100'),
#               ('HUMD', '0.860'),
#               ('PRES', '1011.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '26.100'),
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 09:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.100'),
#               ('TEMP', '24.700'),
#               ('HUMD', '0.910'),
#               ('PRES', '1016.000'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.800'),
#               ('D_TXT', ''),
#               ('D_TN', '23.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 09:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '23.000'),
#               ('WDSD', '3.300'),
#               ('TEMP', '28.400'),
#               ('HUMD', '0.710'),
#               ('PRES', '1015.700'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '28.400'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 09:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '305.000'),
#               ('WDSD', '0.600'),
#               ('TEMP', '27.600'),
#               ('HUMD', '0.810'),
#               ('PRES', '1011.600'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '27.600'),
#               ('D_TXT', ''),
#               ('D_TN', '23.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 09:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '167.000'),
#               ('WDSD', '0.800'),
#               ('TEMP', '29.400'),
#               ('HUMD', '0.670'),
#               ('PRES', '1011.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '29.400'),
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 09:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '15.000'),
#               ('WDSD', '0.700'),
#               ('TEMP', '28.600'),
#               ('HUMD', '0.640'),
#               ('PRES', '968.300'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '28.600'),
#               ('D_TXT', ''),
#               ('D_TN', '21.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 10:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '7.000'),
#               ('WDSD', '4.300'),
#               ('TEMP', '28.900'),
#               ('HUMD', '0.700'),
#               ('PRES', '1015.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '29.100'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 10:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '255.000'),
#               ('WDSD', '1.100'),
#               ('TEMP', '29.000'),
#               ('HUMD', '0.720'),
#               ('PRES', '1011.600'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '29.000'),
#               ('D_TXT', ''),
#               ('D_TN', '23.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 10:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '246.000'),
#               ('WDSD', '1.200'),
#               ('TEMP', '29.900'),
#               ('HUMD', '0.650'),
#               ('PRES', '1011.100'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.200'),
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 10:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '280.000'),
#               ('WDSD', '1.500'),
#               ('TEMP', '27.200'),
#               ('HUMD', '0.710'),
#               ('PRES', '968.100'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '28.600'),
#               ('D_TXT', ''),
#               ('D_TN', '21.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 10:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.100'),
#               ('TEMP', '24.700'),
#               ('HUMD', '0.930'),
#               ('PRES', '1015.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.800'),
#               ('D_TXT', ''),
#               ('D_TN', '23.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 11:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '114.000'),
#               ('WDSD', '0.500'),
#               ('TEMP', '24.700'),
#               ('HUMD', '0.940'),
#               ('PRES', '1015.200'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '24.800'),
#               ('D_TXT', ''),
#               ('D_TN', '23.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 11:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '271.000'),
#               ('WDSD', '1.100'),
#               ('TEMP', '30.900'),
#               ('HUMD', '0.600'),
#               ('PRES', '1011.300'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.900'),
#               ('D_TXT', ''),
#               ('D_TN', '23.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 11:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '180.000'),
#               ('WDSD', '0.900'),
#               ('TEMP', '30.600'),
#               ('HUMD', '0.640'),
#               ('PRES', '1011.000'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.600'),
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 11:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '285.000'),
#               ('WDSD', '1.200'),
#               ('TEMP', '28.500'),
#               ('HUMD', '0.640'),
#               ('PRES', '968.000'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '29.000'),
#               ('D_TXT', ''),
#               ('D_TN', '21.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 11:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '4.000'),
#               ('WDSD', '4.700'),
#               ('TEMP', '29.200'),
#               ('HUMD', '0.700'),
#               ('PRES', '1015.400'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '29.300'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 12:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '358.000'),
#               ('WDSD', '3.600'),
#               ('TEMP', '30.300'),
#               ('HUMD', '0.680'),
#               ('PRES', '1014.700'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.300'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 12:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '206.000'),
#               ('WDSD', '1.000'),
#               ('TEMP', '31.500'),
#               ('HUMD', '0.580'),
#               ('PRES', '1010.700'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '31.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 12:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '186.000'),
#               ('WDSD', '1.200'),
#               ('TEMP', '29.600'),
#               ('HUMD', '0.710'),
#               ('PRES', '1010.900'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.600'),
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 12:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '289.000'),
#               ('WDSD', '1.000'),
#               ('TEMP', '29.600'),
#               ('HUMD', '0.620'),
#               ('PRES', '967.300'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '31.200'),
#               ('D_TXT', ''),
#               ('D_TN', '21.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 13:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '359.000'),
#               ('WDSD', '3.500'),
#               ('TEMP', '30.000'),
#               ('HUMD', '0.690'),
#               ('PRES', '1013.900'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.300'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 13:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '188.000'),
#               ('WDSD', '0.600'),
#               ('TEMP', '32.400'),
#               ('HUMD', '0.540'),
#               ('PRES', '1009.800'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '33.000'),
#               ('D_TXT', ''),
#               ('D_TN', '23.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 13:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '183.000'),
#               ('WDSD', '1.700'),
#               ('TEMP', '29.200'),
#               ('HUMD', '0.730'),
#               ('PRES', '1010.100'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.600'),
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 13:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '246.000'),
#               ('WDSD', '0.900'),
#               ('TEMP', '30.700'),
#               ('HUMD', '0.600'),
#               ('PRES', '966.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '31.200'),
#               ('D_TXT', ''),
#               ('D_TN', '21.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 14:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '58.000'),
#               ('WDSD', '0.800'),
#               ('TEMP', '24.900'),
#               ('HUMD', '0.950'),
#               ('PRES', '1013.300'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '25.000'),
#               ('D_TXT', ''),
#               ('D_TN', '23.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 14:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '234.000'),
#               ('WDSD', '0.500'),
#               ('TEMP', '32.000'),
#               ('HUMD', '0.590'),
#               ('PRES', '1009.100'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '33.000'),
#               ('D_TXT', ''),
#               ('D_TN', '23.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 14:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '162.000'),
#               ('WDSD', '1.300'),
#               ('TEMP', '29.200'),
#               ('HUMD', '0.750'),
#               ('PRES', '1009.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.600'),
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 14:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '316.000'),
#               ('WDSD', '0.700'),
#               ('TEMP', '29.300'),
#               ('HUMD', '0.670'),
#               ('PRES', '966.100'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '31.200'),
#               ('D_TXT', ''),
#               ('D_TN', '21.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 14:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '8.000'),
#               ('WDSD', '4.300'),
#               ('TEMP', '29.700'),
#               ('HUMD', '0.680'),
#               ('PRES', '1013.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 15:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '117.000'),
#               ('WDSD', '0.600'),
#               ('TEMP', '25.000'),
#               ('HUMD', '0.950'),
#               ('PRES', '1013.400'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '25.000'),
#               ('D_TXT', ''),
#               ('D_TN', '23.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 15:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '13.000'),
#               ('WDSD', '4.700'),
#               ('TEMP', '28.600'),
#               ('HUMD', '0.760'),
#               ('PRES', '1013.200'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 15:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '356.000'),
#               ('WDSD', '2.300'),
#               ('TEMP', '30.000'),
#               ('HUMD', '0.700'),
#               ('PRES', '1009.100'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '33.000'),
#               ('D_TXT', ''),
#               ('D_TN', '23.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 15:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '161.000'),
#               ('WDSD', '1.000'),
#               ('TEMP', '29.000'),
#               ('HUMD', '0.770'),
#               ('PRES', '1009.300'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.600'),
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 15:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '27.000'),
#               ('WDSD', '0.500'),
#               ('TEMP', '28.800'),
#               ('HUMD', '0.730'),
#               ('PRES', '965.900'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '31.200'),
#               ('D_TXT', ''),
#               ('D_TN', '21.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 16:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.000'),
#               ('TEMP', '24.900'),
#               ('HUMD', '0.950'),
#               ('PRES', '1013.200'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '25.000'),
#               ('D_TXT', ''),
#               ('D_TN', '23.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 16:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '7.000'),
#               ('WDSD', '3.700'),
#               ('TEMP', '27.900'),
#               ('HUMD', '0.790'),
#               ('PRES', '1013.300'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 16:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '344.000'),
#               ('WDSD', '3.100'),
#               ('TEMP', '29.000'),
#               ('HUMD', '0.740'),
#               ('PRES', '1009.400'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '33.000'),
#               ('D_TXT', ''),
#               ('D_TN', '23.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 16:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '167.000'),
#               ('WDSD', '1.100'),
#               ('TEMP', '28.600'),
#               ('HUMD', '0.800'),
#               ('PRES', '1009.300'),
# ...
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 18:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '280.000'),
#               ('WDSD', '0.600'),
#               ('TEMP', '26.100'),
#               ('HUMD', '0.850'),
#               ('PRES', '965.900'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '31.200'),
#               ('D_TXT', ''),
#               ('D_TN', '21.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 18:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '6.000'),
#               ('WDSD', '2.900'),
#               ('TEMP', '26.700'),
#               ('HUMD', '0.850'),
#               ('PRES', '1013.300'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 19:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '6.000'),
#               ('WDSD', '2.100'),
#               ('TEMP', '26.500'),
#               ('HUMD', '0.870'),
#               ('PRES', '1013.600'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 19:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '331.000'),
#               ('WDSD', '2.500'),
#               ('TEMP', '26.700'),
#               ('HUMD', '0.870'),
#               ('PRES', '1010.000'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '33.000'),
#               ('D_TXT', ''),
#               ('D_TN', '23.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 19:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '140.000'),
#               ('WDSD', '0.700'),
#               ('TEMP', '26.500'),
#               ('HUMD', '0.920'),
#               ('PRES', '1009.900'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.600'),
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 19:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '327.000'),
#               ('WDSD', '0.900'),
#               ('TEMP', '25.600'),
#               ('HUMD', '0.890'),
#               ('PRES', '966.100'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '31.200'),
#               ('D_TXT', ''),
#               ('D_TN', '21.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 19:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '39.000'),
#               ('WDSD', '1.500'),
#               ('TEMP', '23.100'),
#               ('HUMD', '0.950'),
#               ('PRES', '1014.600'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '8.800'),
#               ('H_XD', '138.000'),
#               ('H_FXT', ''),
#               ('D_TX', '25.000'),
#               ('D_TXT', ''),
#               ('D_TN', '23.000'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 20:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '275.000'),
#               ('WDSD', '1.000'),
#               ('TEMP', '22.300'),
#               ('HUMD', '0.960'),
#               ('PRES', '1014.700'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '25.000'),
#               ('D_TXT', ''),
#               ('D_TN', '22.300'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 20:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '344.000'),
#               ('WDSD', '1.300'),
#               ('TEMP', '26.300'),
#               ('HUMD', '0.900'),
#               ('PRES', '1010.700'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '33.000'),
#               ('D_TXT', ''),
#               ('D_TN', '23.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 20:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '22.000'),
#               ('WDSD', '3.000'),
#               ('TEMP', '26.300'),
#               ('HUMD', '0.880'),
#               ('PRES', '1014.100'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 20:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.100'),
#               ('TEMP', '25.900'),
#               ('HUMD', '0.960'),
#               ('PRES', '1010.200'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.600'),
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 20:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.200'),
#               ('TEMP', '24.900'),
#               ('HUMD', '0.920'),
#               ('PRES', '966.800'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '31.200'),
#               ('D_TXT', ''),
#               ('D_TN', '21.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 21:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '39.000'),
#               ('WDSD', '1.900'),
#               ('TEMP', '26.200'),
#               ('HUMD', '0.880'),
#               ('PRES', '1014.800'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 21:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '4.000'),
#               ('WDSD', '1.000'),
#               ('TEMP', '26.100'),
#               ('HUMD', '0.920'),
#               ('PRES', '1011.300'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '33.000'),
#               ('D_TXT', ''),
#               ('D_TN', '23.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 21:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.100'),
#               ('TEMP', '25.200'),
#               ('HUMD', '0.980'),
#               ('PRES', '1010.700'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.600'),
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 21:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '231.000'),
#               ('WDSD', '0.600'),
#               ('TEMP', '24.800'),
#               ('HUMD', '0.910'),
#               ('PRES', '967.300'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '31.200'),
#               ('D_TXT', ''),
#               ('D_TN', '21.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 21:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '308.000'),
#               ('WDSD', '1.200'),
#               ('TEMP', '22.300'),
#               ('HUMD', '0.960'),
#               ('PRES', '1014.800'),
#               ('SUN', ''),
#               ('H_24R', '-99.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '25.000'),
#               ('D_TXT', ''),
#               ('D_TN', '22.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 22:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '221.000'),
#               ('WDSD', '0.900'),
#               ('TEMP', '22.300'),
#               ('HUMD', '0.960'),
#               ('PRES', '1013.900'),
#               ('SUN', ''),
#               ('H_24R', '-99.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '25.000'),
#               ('D_TXT', ''),
#               ('D_TN', '22.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 22:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '31.000'),
#               ('WDSD', '1.500'),
#               ('TEMP', '25.900'),
#               ('HUMD', '0.880'),
#               ('PRES', '1014.700'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 22:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '43.000'),
#               ('WDSD', '0.900'),
#               ('TEMP', '26.000'),
#               ('HUMD', '0.920'),
#               ('PRES', '1011.000'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '33.000'),
#               ('D_TXT', ''),
#               ('D_TN', '23.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 22:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '136.000'),
#               ('WDSD', '0.400'),
#               ('TEMP', '24.900'),
#               ('HUMD', '0.990'),
#               ('PRES', '1010.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.600'),
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 22:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.000'),
#               ('TEMP', '24.400'),
#               ('HUMD', '0.940'),
#               ('PRES', '967.200'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '31.200'),
#               ('D_TXT', ''),
#               ('D_TN', '21.600'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '2019-09-27 23:00:00'),
#               ('ELEV', '39.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.000'),
#               ('TEMP', '26.000'),
#               ('HUMD', '0.920'),
#               ('PRES', '1010.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '33.000'),
#               ('D_TXT', ''),
#               ('D_TN', '23.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '2019-09-27 23:00:00'),
#               ('ELEV', '6.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.000'),
#               ('TEMP', '22.400'),
#               ('HUMD', '0.960'),
#               ('PRES', '1014.000'),
#               ('SUN', ''),
#               ('H_24R', '-99.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '25.000'),
#               ('D_TXT', ''),
#               ('D_TN', '22.100'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '2019-09-27 23:00:00'),
#               ('ELEV', '17.000'),
#               ('WDIR', '18.000'),
#               ('WDSD', '0.300'),
#               ('TEMP', '25.700'),
#               ('HUMD', '0.880'),
#               ('PRES', '1014.200'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.500'),
#               ('D_TXT', ''),
#               ('D_TN', '23.800'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '2019-09-27 23:00:00'),
#               ('ELEV', '32.000'),
#               ('WDIR', '185.000'),
#               ('WDSD', '0.400'),
#               ('TEMP', '24.600'),
#               ('HUMD', '0.990'),
#               ('PRES', '1010.500'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '30.600'),
#               ('D_TXT', ''),
#               ('D_TN', '22.400'),
#               ('D_TNT', '')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '2019-09-27 23:00:00'),
#               ('ELEV', '425.000'),
#               ('WDIR', '0.000'),
#               ('WDSD', '0.000'),
#               ('TEMP', '24.200'),
#               ('HUMD', '0.960'),
#               ('PRES', '966.700'),
#               ('SUN', ''),
#               ('H_24R', '0.000'),
#               ('H_FX', '-99.000'),
#               ('H_XD', '-99.000'),
#               ('H_FXT', '-99.000'),
#               ('D_TX', '31.200'),
#               ('D_TXT', ''),
#               ('D_TN', '21.600'),
#               ('D_TNT', '')])]

# %%
len(filt_data)
# Out:
# 7

# %%
filt_data
# Out:
# [OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '00:00'),
#               ('WDSD', '12.0'),
#               ('TEMP', '22.0'),
#               ('HUMD', '0.65'),
#               ('PRES', '1007.0')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '12:00'),
#               ('WDSD', '11.0'),
#               ('TEMP', '22.0'),
#               ('HUMD', '0.67'),
#               ('PRES', '1014.3')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '00:00'),
#               ('WDSD', '13.0'),
#               ('TEMP', '28.0'),
#               ('HUMD', '-99.000'),
#               ('PRES', '-99.000')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '12:00'),
#               ('WDSD', '17.0'),
#               ('TEMP', '28.0'),
#               ('HUMD', '0.43'),
#               ('PRES', '995.1')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '00:00'),
#               ('WDSD', '0.0'),
#               ('TEMP', '-99.000'),
#               ('HUMD', '0.53'),
#               ('PRES', '-99.000')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '12:00'),
#               ('WDSD', '19.0'),
#               ('TEMP', '27.0'),
#               ('HUMD', '0.55'),
#               ('PRES', '-99.000')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '00:00'),
#               ('WDSD', '-99.000'),
#               ('TEMP', '-99.000'),
#               ('HUMD', '0.67'),
#               ('PRES', '1018.5')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '12:00'),
#               ('WDSD', '19.0'),
#               ('TEMP', '-99.000'),
#               ('HUMD', '0.69'),
#               ('PRES', '1017.4')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '00:00'),
#               ('WDSD', '-99.000'),
#               ('TEMP', '27.0'),
#               ('HUMD', '-99.000'),
#               ('PRES', '1013.5')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '12:00'),
#               ('WDSD', '-99.000'),
#               ('TEMP', '27.0'),
#               ('HUMD', '-99.000'),
#               ('PRES', '1001.8')])]

# %%
len(filt_data)
# Out:
# 10

# %%
filt_data
# Out:
# [OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '00:00'),
#               ('WDSD', '12.0'),
#               ('TEMP', '22.0'),
#               ('HUMD', '0.65'),
#               ('PRES', '1007.0')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '12:00'),
#               ('WDSD', '11.0'),
#               ('TEMP', '22.0'),
#               ('HUMD', '0.67'),
#               ('PRES', '1014.3')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '00:00'),
#               ('WDSD', '13.0'),
#               ('TEMP', '28.0'),
#               ('HUMD', '-99.000'),
#               ('PRES', '-99.000')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '12:00'),
#               ('WDSD', '17.0'),
#               ('TEMP', '28.0'),
#               ('HUMD', '0.43'),
#               ('PRES', '995.1')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '00:00'),
#               ('WDSD', '0.0'),
#               ('TEMP', '-99.000'),
#               ('HUMD', '0.53'),
#               ('PRES', '-99.000')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '12:00'),
#               ('WDSD', '19.0'),
#               ('TEMP', '27.0'),
#               ('HUMD', '0.55'),
#               ('PRES', '-99.000')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '00:00'),
#               ('WDSD', '-99.000'),
#               ('TEMP', '-99.000'),
#               ('HUMD', '0.67'),
#               ('PRES', '1018.5')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '12:00'),
#               ('WDSD', '19.0'),
#               ('TEMP', '-99.000'),
#               ('HUMD', '0.69'),
#               ('PRES', '1017.4')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '00:00'),
#               ('WDSD', '-99.000'),
#               ('TEMP', '27.0'),
#               ('HUMD', '-99.000'),
#               ('PRES', '1013.5')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '12:00'),
#               ('WDSD', '-99.000'),
#               ('TEMP', '27.0'),
#               ('HUMD', '-99.000'),
#               ('PRES', '1001.8')])]

# %%
filt_data
# Out:
# [OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '00:00'),
#               ('WDSD', '12.0'),
#               ('TEMP', '22.0'),
#               ('HUMD', '0.65'),
#               ('PRES', '1007.0')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '12:00'),
#               ('WDSD', '11.0'),
#               ('TEMP', '22.0'),
#               ('HUMD', '0.67'),
#               ('PRES', '1014.3')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '00:00'),
#               ('WDSD', '13.0'),
#               ('TEMP', '28.0'),
#               ('HUMD', '-99.000'),
#               ('PRES', '-99.000')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '12:00'),
#               ('WDSD', '17.0'),
#               ('TEMP', '28.0'),
#               ('HUMD', '0.43'),
#               ('PRES', '995.1')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '00:00'),
#               ('WDSD', '0.0'),
#               ('TEMP', '-99.000'),
#               ('HUMD', '0.53'),
#               ('PRES', '-99.000')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '12:00'),
#               ('WDSD', '19.0'),
#               ('TEMP', '27.0'),
#               ('HUMD', '0.55'),
#               ('PRES', '-99.000')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '00:00'),
#               ('WDSD', '-99.000'),
#               ('TEMP', '-99.000'),
#               ('HUMD', '0.67'),
#               ('PRES', '1018.5')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '12:00'),
#               ('WDSD', '19.0'),
#               ('TEMP', '-99.000'),
#               ('HUMD', '0.69'),
#               ('PRES', '1017.4')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '00:00'),
#               ('WDSD', '-99.000'),
#               ('TEMP', '27.0'),
#               ('HUMD', '-99.000'),
#               ('PRES', '1013.5')]),
#  OrderedDict([('station_id', 'C0A880'),
#               ('obsTime', '12:00'),
#               ('WDSD', '-99.000'),
#               ('TEMP', '27.0'),
#               ('HUMD', '-99.000'),
#               ('PRES', '1001.8')])]

# %%
len(filt_data)
# Out:
# 7

# %%
filt_data
# Out:
# [OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '00:00'),
#               ('WDSD', '12.0'),
#               ('TEMP', '22.0'),
#               ('HUMD', '0.65'),
#               ('PRES', '1007.0')]),
#  OrderedDict([('station_id', 'C0F9A0'),
#               ('obsTime', '12:00'),
#               ('WDSD', '11.0'),
#               ('TEMP', '22.0'),
#               ('HUMD', '0.67'),
#               ('PRES', '1014.3')]),
#  OrderedDict([('station_id', 'C0G640'),
#               ('obsTime', '12:00'),
#               ('WDSD', '17.0'),
#               ('TEMP', '28.0'),
#               ('HUMD', '0.43'),
#               ('PRES', '995.1')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '00:00'),
#               ('WDSD', '0.0'),
#               ('TEMP', '-99.000'),
#               ('HUMD', '0.53'),
#               ('PRES', '-99.000')]),
#  OrderedDict([('station_id', 'C0X260'),
#               ('obsTime', '12:00'),
#               ('WDSD', '19.0'),
#               ('TEMP', '27.0'),
#               ('HUMD', '0.55'),
#               ('PRES', '-99.000')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '00:00'),
#               ('WDSD', '-99.000'),
#               ('TEMP', '-99.000'),
#               ('HUMD', '0.67'),
#               ('PRES', '1018.5')]),
#  OrderedDict([('station_id', 'C0R190'),
#               ('obsTime', '12:00'),
#               ('WDSD', '19.0'),
#               ('TEMP', '-99.000'),
#               ('HUMD', '0.69'),
#               ('PRES', '1017.4')])]

# %%
station
# Out:
# ['C0F9A0', 'C0G640', 'C0X260', 'C0R190']

# %%
humd
# Out:
# [1.32, '0.43', 1.08, 1.3599999999999999, 'None']

# %%
[station,humd]
# Out:
# [['C0F9A0', 'C0G640', 'C0X260', 'C0R190', 'C0A880'],
#  [1.32, '0.43', 1.08, 1.3599999999999999, 'None']]

# %%
station
# Out:
# ['C0F9A0', 'C0G640', 'C0X260', 'C0R190']

# %%
target_data
# Out:
# [['C0F9A0', 1.32],
#  ['C0G640', '0.43'],
#  ['C0X260', 1.08],
#  ['C0R190', 1.3599999999999999],
#  ['C0A880', 'None']]
